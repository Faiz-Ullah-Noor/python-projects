# %%
adj: str = input("When I doing computer programming its make me very: ")
verb1: str = input("When I doing: ")
verb2: str = input("I make my self before: ")
famous_person: str = input("I feel like I am: ")
madlib :str  = f"""
When I doing computer programming its make me very {adj},
When I doing {verb1} daily , I make my self before {verb2}
and I feel like I am {famous_person}
"""
print(madlib)
# Out:
# When I doing computer programming its make me very: happy
# When I doing: programming
# I make my self before: energic
# I feel like I am: khabib
#
# When I doing computer programming its make me very happy,
# When I doing programming daily , I make my self before energic
# and I feel like I am khabib
