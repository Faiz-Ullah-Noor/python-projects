# %%
import random

print("Welcome to your password generator")

char = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!@#$%^&*()_-=+<>?,./;'1234567890"

number = int(input("Enter the amount of passwords you want to generate: "))

length = int(input("Enter the length of each password: "))

print("Here is your password: ")

for password in range(number):
    passwords = ""
    for c in range(length):
        passwords += random.choice(char)
    print(passwords)
# Out:
# Welcome to your password generator
# Enter the amount of passwords you want to generate: 5
# Enter the length of each password: 5
# Here is your password:
# 5qz*e
# 5jfIG
# P+223
# Nr^uT
# !^HH?
